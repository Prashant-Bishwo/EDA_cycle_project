# %% [markdown]
# ## The objective of this analysis is to examine the relationship between age and G3 among school school childern.

# %%
import pandas as pd #data manipulation
import numpy as np # numerical python matrix
import matplotlib.pyplot as plt # GRAPH 
import seaborn as sns 
# %matplotlib inline 
from scipy.stats import skew # Skewness

# %%
df = pd.read_csv("student-mat.csv") # first read the data file

# %%
df.head() # quick look to dataset . show  first 5 data row as default
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
df.tail() #  show last five data row as default .
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 390  ...      5        5      4     4     5      4       11   9   9   9
# 391  ...      2        4      5     3     4      2        3  14  16  16
# 392  ...      5        5      3     3     3      3        3  10   8   7
# 393  ...      4        4      1     3     4      5        0  11  12  10
# 394  ...      3        2      3     3     3      5        5   8   9   9
#
# [5 rows x 33 columns]

# %%
df.shape #  show total rows and columns present in the dataset.
# Out:
# (395, 33)

# %% [markdown]
# We have 395 rows of data and 33 columns
# 395*33 = 13035 no of data points(cells).

# %%
df.describe() # it prints summary statistics.
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
#No missing data as all count have 395 data
#mean age is 16
#max age i 22.
#average marks - 10.41 
#max marks is 20

# %%
df.info()   #the complete information about the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %% [markdown]
# Data type - 16 interger 17 objeect/string
# We have 16 columns with int64(numeric)
# 17 are catagories data(object)
# So when creating the correaltion or anything we need to
# change it to machine understable i.e 1 and 0( it is called encoding)

# %%
print(df.isnull().values.sum())
# Out:
# 0

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
# Replace the ' 's with NaN
df = df.replace(" ",np.NaN)

# %%
# Count the number of NaNs in the dataset to verify
print(df.isnull().values.sum())
# Out:
# 0

# %%
df['sex'].value_counts()
# Out:
# sex
# F    208
# M    187
# Name: count, dtype: int64

# %%
# Set style
sns.set_style("whitegrid")

# Defining a color palette with needed colors (blue and orange):
colors = ["#20b2aa", "#ff7f0e"]  # Blue and orange
sns.set_palette(sns.color_palette(colors))

# Plot histogram with hue parameter and without legend
sns.histplot(data=df, x="sex", hue="sex", multiple="stack", legend=True)

# Remove labels
plt.title('How many people are female and male?', fontsize=16)
plt.xlabel('Sex', fontsize=14)
plt.ylabel('No. of People', fontsize=14)

# Show plot
plt.show()

# %% [markdown]
# Female are more compared to Male.
# Female comprised of 208 and male 187.
# With this we can say that data is imbalanced-
# meaning the analysis we do will likely be more influenced to the female.
# (So we need to do data imbalance treatment)

# %%
# Set the style and context for a minimal look
sns.set(style="white", context="talk")

# Create the histogram plot
plt.figure(figsize=(10, 6))
ax = sns.histplot(data=df, x="age", kde=False, color='skyblue', edgecolor='black', linewidth=1.2, bins=6)

# Add a title and labels with a larger font size for better readability
ax.set_title('Age Distribution', fontsize=20, weight='bold')
ax.set_xlabel('Age', fontsize=15)
ax.set_ylabel('Frequency', fontsize=15)

# Customize the appearance of the KDE line
for line in ax.lines:
    line.set_color('darkblue')
    line.set_linewidth(2.5)

# Remove grid lines
ax.grid(False)

# Customize the tick parameters
ax.tick_params(axis='both', which='major', labelsize=12)

# Remove the top and right spines for a minimal look
sns.despine()

# Show the plot
plt.show()

# %% [markdown]
# The age distribution shows that it is skewness(right)
# Since it is not normal distirbution, all the analysis we do for age, we might not get to concreate fiding.
# Taking bin size of 6 we see, most of age group we have is 15-16 years old.

# %%
# Calculate skewness
skewness = skew(df["age"])

# Print the skewness value
print("Skewness:", skewness)
# Out:
# Skewness: 0.4644976441488073

# %% [markdown]
# The distribution of age values is moderately skewed to the right.( the mean is typically greater than the median)
#
# Most of the age values are concentrated on the younger side, with fewer older ages stretching out to the right.
#
# The mean age might not be the best central tendency measure due to the skewness. The median could provide a better central value.(So we do not good to say Mean age is this)
#
# To normalize the data, we can apply transformations such as logarithmic, square root, or Box-Cox transformations

# %%
# Assuming 'df' is your DataFrame and it is already loaded
sns.set(style="whitegrid")  # Setting the theme

# Creating the scatterplot
plt.figure(figsize=(10, 6))  # Adjusting the figure size
scatter = sns.scatterplot(data=df, y="age", x="G3", s=100, color="blue", edgecolor="w", linewidth=1.5)

# Customizing the plot
scatter.set_title("Scatterplot of Age vs G3", fontsize=16)
scatter.set_xlabel("G3", fontsize=14)
scatter.set_ylabel("Age", fontsize=14)
plt.tight_layout()

# Displaying the plot
plt.show()

# %% [markdown]
# Looking at the Scatterplot we find the relationship of G3 and age.
# Age Range: The ages of the students range from 15 to 22.
# G3 Range: The final grades (G3) range from 0 to 20.
# Most of the data points are concentrated in the age range of 15 to 18.
# Fewer data points for ages above 20 ( it might be outliers).
# For younger students (ages 15-18), there is a broader spread of G3 scores.
# The age of 16 has the highest mark 20.
# tlier

# %% [markdown]
# The avobe figure showing scatterplot between age and G3 .

# %%
sns.set(style="whitegrid")  # Setting the theme

# Creating the scatterplot
plt.figure(figsize=(10, 6))  # Adjusting the figure size
scatter = sns.scatterplot(data=df, y="age", x="G3", hue="sex", style="sex", palette="deep")

# Customizing the plot
scatter.set_title("Scatterplot of Age vs G3", fontsize=16)
scatter.set_xlabel("G3", fontsize=14)
scatter.set_ylabel("Age", fontsize=14)
plt.legend(title='Gender', loc='best')
plt.tight_layout()

# Displaying the plot
plt.show()

# %% [markdown]
# Gender Distribution:
# Female students are represented by blue dots.
# Male students are represented by orange crosses.
# Higher density of male students in the upper age range (19-22).
# No clear trend favoring one gender over the other.
# Older male students ages 20 with high G3 scores.
# Students with a G3 score of 0 are present more in female genders.

# %%
# Creating the line plot
plt.figure(figsize=(12, 8))  # Adjusting the figure size
line_plot = sns.lineplot(y='G3', x='age', data=df, marker='o', color='blue', linewidth=2.5)

# Customizing the plot
line_plot.set_title("Line Plot of G3 vs Age", fontsize=20, weight='bold')
line_plot.set_xlabel("Age", fontsize=16)
line_plot.set_ylabel("G3", fontsize=16)
line_plot.tick_params(labelsize=14)  # Adjusting tick label size
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()

# Displaying the plot
plt.show()

# %% [markdown]
# The above figure is line plot between age and G3. Blue shade showing confidence interval.
# Decreasing trend in G3 scores from age 15 to 19.
# G3 score decreases from around 12 at age 15 to about 8 at age 19.
# Significant increase in the average G3 score at age 20, with a wider confidence interval indicating greater variability in scores.
# The average G3 score drops sharply at age 21 to around 6.
# The confidence interval is relatively narrow from ages 15 to 19, suggesting consistent performance within those age groups.

# %%
# Creating the box plot
plt.figure(figsize=(12, 8))  # Adjusting the figure size
box_plot = sns.boxplot(y='age', x='G3', data=df, palette="pastel")

# Customizing the plot
box_plot.set_title("Box Plot of Age by G3", fontsize=20, weight='bold')
box_plot.set_xlabel("G3", fontsize=16)
box_plot.set_ylabel("Age", fontsize=16)
box_plot.tick_params(labelsize=14)  # Adjusting tick label size
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()

# Displaying the plot
plt.show()
# Out:
# C:\Users\L E N O V O\AppData\Local\Temp\ipykernel_18660\3325955650.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   box_plot = sns.boxplot(y='age', x='G3', data=df, palette="pastel")

# %% [markdown]
# The above figure showing box plot between age and G3.
# Most grades have a median age around 17.
# Some grades G3=8 and G3= 12) show outliers.
# No clear trend in age distribution with respect to final grades.

# %%
# Select all categorical columns
categorical_cols = df.select_dtypes(include=['object']).columns 
# Encode categorical columns 
df[categorical_cols] = df[categorical_cols].apply(lambda col: col.astype('category').cat.codes) 
# Verify encoding
print("\nEncoded Data:\n", df) 
corr_matrix = df.corr()
# Calculate correlation matrix corr_matrix = df.corr()
 # Plot heatmap
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
# show graphs
plt.show()

# encode non numerical data into numerical data form .
# Out:
# Encoded Data:
#       school  sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  ...  \
# 0         0    0   18        1        0        0     4     4     0     4  ...
# 1         0    0   17        1        0        1     1     1     0     2  ...
# 2         0    0   15        1        1        1     1     1     0     2  ...
# 3         0    0   15        1        0        1     4     2     1     3  ...
# 4         0    0   16        1        0        1     3     3     2     2  ...
# ..      ...  ...  ...      ...      ...      ...   ...   ...   ...   ...  ...
# 390       1    1   20        1        1        0     2     2     3     3  ...
# 391       1    1   17        1        1        1     3     1     3     3  ...
# 392       1    1   21        0        0        1     1     1     2     2  ...
# 393       1    1   18        0        1        1     3     2     3     2  ...
# 394       1    1   19        1        1        1     1     1     2     0  ...
#
# ...

# %%
# Using One-Hot Encoding for categorical columns to change to numeric
df_encoded = pd.get_dummies(df, drop_first=True)

# Calculate the correlation matrix
correlation_matrix = df_encoded.corr()

# Setting the style
sns.set(style="white")

# Creating the heatmap
plt.figure(figsize=(40, 40))  # Adjusting the figure size
heatmap = sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm',
                       square=True, cbar_kws={"shrink": .8}, linewidths=.5,
                       annot_kws={"size": 10, "weight": "bold"},  # Customizing annotation size and weight
                       cbar=True)  # Show color bar

# Customizing the plot
heatmap.set_title("Correlation Heatmap", fontsize=22, weight='bold')
plt.xticks(fontsize=14, rotation=45)  # Rotating x-axis labels for better readability
plt.yticks(fontsize=14)
plt.tight_layout()

# Displaying the plot
plt.show()

# %% [markdown]
# The heatmap shows the Pearson correlation coefficients between all pairs of variables in the dataset.The value ranges from -1 to 1, where 1 implies a perfect positive correlation, -1 implies a perfect negative correlation, and 0 implies no correlation.
#
# The correlation between age and G3 is -0.16, which shows that a negative correlation between age and G3 would imply that older students are slightly more likely to have lower final grades compared to younger students.

# %% [markdown]
# # Data Analysis Report: Relationship Between Age and G3 for Portugues School Children
#
# ## Objective
# The primary objective of this analysis is to examine the relationship between age and G3 among students.
#
# ## Data Overview
# - **Total Data Points**: 359
# - **Age Range**: Minimum age of 15 years; Maximum age of 22 years.
# - **Mean Age**: 16 years.
#   - Average marks obtained : 10.41.
#
# - **Data Types**:
#   - Numeric (int64): 16 columns
#   - Categorical (object): 17 columns
# - **Gender Distribution**:
#   - Females: 208
#   - Males: 187
#   - Notably, the dataset is imbalanced, with a higher representation of females.
#
# ## Data Characteristics
# ### Age Distribution
# - **Skewness**: The age distribution shows right skewness, indicating that the mean age is greater than the median.
# - **Bin Size**: A bin size of 6 reveals that the majority of the age group falls between 15 and 16 years.
# - **Concentration**: Most age values are concentrated on the younger side, with fewer older ages extending to the right.
#
#
# ### Central Tendency
# - Due to the right skewness, the mean age may not be the best representation of central tendency. The median age provides a better central value.
#
# ### Final grade/marks obtain by Age
# - Datapoints are concentrated at 15 to 18.
# - The age of 16 has higher marks of 20.
# - No clear trend favoring one gender over the other.
#
# ### Gender Analysis
# - The age 22 is represented only by male data, with no female records, indicating an outlier.
# - Higher marks were obtain by those aged 16, with males showing higher marks obtain overall.
# - No clear trend favoring one gender over the other.
#
# ### Box Plot Insights
# - The box plot analysis reveals:
#   - Most grades have a median age around 17
#   - Some grades G3=8 and G3= 12) show outliers.
#   - No clear trend in age distribution with respect to final grades.
#   - There is an outlier for males at age 22.
#
#
# ## Correlation Analysis
# - **Age and G3**:The correlation between age and G3 is -0.16, indicates a weak negative correlation. Older students are  more likely to have lower final grades compared to younger, though this is not a strong predictor.
# - **Absences and Final Grades**: Correlation coefficient of 0.03 shows a weak positive correlation, implying that higher absences are associated with lower final.
# - **Study time and final grade(G3)**: A weak positive correlation of 0.10 suggests that as studytime increases, the final grade(G3) also increases.
#
# ## Conclusion
# The analysis reveals a weak negative correlation (-0.16) between age and G3, Older students are  more likely to have lower final grades compared to younger, though this is not a strong predictor. Additionally, the dataset is imbalanced in terms of gender representation, which may influence the analysis outcomes.
